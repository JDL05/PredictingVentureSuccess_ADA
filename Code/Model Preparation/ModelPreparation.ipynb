# %% [markdown]
# # Model Preparation

# %% [markdown]
# ## Import Packages

# %%
from importnb import Notebook
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data-Import from 'Feature Engineering'

# %%
# with Notebook():
#    from FeatureEngineering import companies

# %% [markdown]
# ## Manual Upload

# %%
companies = pd.read_csv('/Users/janlinzner/Library/Mobile Documents/com~apple~CloudDocs/Documents/McGill/1_Lectures/Decision Analytics (MGSC 662)/2_Coding/Exercises/ADA_Coding/Code/companies.csv')

# %% [markdown]
# ## Success Definition

# %%
data = companies

data['Success'] = ((data['Was Acquired'] == 1) |
                   (data['IPO'] == 1) |
                   (data['High Funding'] == 1)).astype(int)

data['Success'].value_counts(normalize=True) * 100
# Out:
# Success
# 0    82.516556
# 1    17.483444
# Name: proportion, dtype: float64

# %% [markdown]
# ## Data Preparation

# %%
# Remove non-numeric columns
data = data.select_dtypes(include=[np.number])

# count nan values
nan_values = data.isna().sum()
nan_values = nan_values[nan_values > 0]
print(nan_values)

# count rows
rows=data.shape[0]
print(f"Remaining rows after dropping NaNs: {rows}")
# Out:
# Series([], dtype: int64)
# Remaining rows after dropping NaNs: 1510

# %% [markdown]
# ## Correlation Analysis

# %%
correlation_matrix = data.corr()
correlation_matrix
# Out:
#                                      ID  Number of Founders  \
# ID                             1.000000           -0.084895
# Number of Founders            -0.084895            1.000000
# Number of Employees            0.027433            0.067437
# Number of Funding Rounds      -0.082856            0.247724
# Last Funding Amount           -0.077844            0.051632
# ...                                 ...                 ...
# Decade Experience Ratio       -0.082334            0.158505
# Mid Career Experience Ratio    0.040077            0.037785
# Avg Gaps in Experience        -0.048625            0.068494
# Avg Longest Position Duration -0.062238            0.130321
# Success                       -0.082291            0.155821
#
#                                Number of Employees  Number of Funding Rounds  \
# ID                                        0.027433                 -0.082856
# Number of Founders                        0.067437                  0.247724
# Number of Employees                       1.000000                  0.197567
# Number of Funding Rounds                  0.197567                  1.000000
# Last Funding Amount                       0.196586                  0.190573
# ...                                            ...                       ...
# Decade Experience Ratio                   0.014902                  0.251902
# Mid Career Experience Ratio              -0.030265                  0.015520
# Avg Gaps in Experience                   -0.003104                  0.062280
# Avg Longest Position Duration            -0.006128                  0.210512
# Success                                   0.158586                  0.256907
#
#                                Last Funding Amount  Total Funding Amount  \
# ID                                       -0.077844             -0.045215
# Number of Founders                        0.051632              0.088970
# Number of Employees                       0.196586              0.377279
# Number of Funding Rounds                  0.190573              0.444640
# Last Funding Amount                       1.000000              0.434228
# ...                                            ...                   ...
# Decade Experience Ratio                   0.061448              0.076468
# Mid Career Experience Ratio              -0.033493             -0.012166
# Avg Gaps in Experience                    0.044697              0.009897
# Avg Longest Position Duration             0.042071              0.054996
# Success                                   0.214912              0.149670
#
#                                Number of Lead Investors  Number of Investors  \
# ID                                            -0.086429            -0.082165
# Number of Founders                             0.247668             0.209317
# Number of Employees                            0.226993             0.239652
# Number of Funding Rounds                       0.718917             0.696856
# Last Funding Amount                            0.281774             0.259982
# ...                                                 ...                  ...
# Decade Experience Ratio                        0.210580             0.219617
# Mid Career Experience Ratio                   -0.009436             0.031973
# Avg Gaps in Experience                         0.062898             0.097013
# Avg Longest Position Duration                  0.146385             0.172314
# Success                                        0.300675             0.270534
#
#                                Number of Acquisitions       IPO  ...  \
# ID                                          -0.013106  0.019156  ...
# Number of Founders                           0.045087  0.012097  ...
# Number of Employees                          0.219280  0.192639  ...
# Number of Funding Rounds                     0.172375  0.107846  ...
# Last Funding Amount                          0.150631  0.145310  ...
# ...                                               ...       ...  ...
# Decade Experience Ratio                      0.051477 -0.024383  ...
# Mid Career Experience Ratio                 -0.009940 -0.015696  ...
# Avg Gaps in Experience                       0.003017 -0.008651  ...
# Avg Longest Position Duration                0.081388 -0.036202  ...
# Success                                      0.077012  0.168224  ...
#
#                                Any Researcher  Executive Ratio  \
# ID                                  -0.041584        -0.008301
# Number of Founders                   0.279381         0.112080
# Number of Employees                  0.023217        -0.024837
# Number of Funding Rounds             0.226397         0.021510
# Last Funding Amount                  0.029889        -0.059618
# ...                                       ...              ...
# Decade Experience Ratio              0.341374         0.321491
# Mid Career Experience Ratio          0.088675         0.257217
# Avg Gaps in Experience               0.041767         0.224672
# Avg Longest Position Duration        0.298774         0.388172
# Success                              0.073434         0.106368
#
#                                All Executives  Any Executive  \
# ID                                  -0.006229      -0.004639
# Number of Founders                  -0.054427       0.240416
# Number of Employees                 -0.033413      -0.018909
# Number of Funding Rounds            -0.052851       0.101224
# Last Funding Amount                 -0.083051      -0.022159
# ...                                       ...            ...
# Decade Experience Ratio              0.236377       0.353794
# Mid Career Experience Ratio          0.209612       0.248854
# Avg Gaps in Experience               0.173937       0.235237
# Avg Longest Position Duration        0.299016       0.408194
# Success                              0.042394       0.144854
#
#                                Few Years Experience Ratio  \
# ID                                               0.005081
# Number of Founders                               0.040352
# Number of Employees                             -0.003643
# Number of Funding Rounds                         0.020996
# Last Funding Amount                             -0.006909
# ...                                                   ...
# Decade Experience Ratio                         -0.077749
# Mid Career Experience Ratio                      0.003076
# Avg Gaps in Experience                           0.023015
# Avg Longest Position Duration                   -0.034092
# Success                                          0.044780
#
#                                Decade Experience Ratio  \
# ID                                           -0.082334
# Number of Founders                            0.158505
# Number of Employees                           0.014902
# Number of Funding Rounds                      0.251902
# Last Funding Amount                           0.061448
# ...                                                ...
# Decade Experience Ratio                       1.000000
# Mid Career Experience Ratio                  -0.317491
# Avg Gaps in Experience                        0.333269
# Avg Longest Position Duration                 0.801888
# Success                                       0.104709
#
#                                Mid Career Experience Ratio  \
# ID                                                0.040077
# Number of Founders                                0.037785
# Number of Employees                              -0.030265
# Number of Funding Rounds                          0.015520
# Last Funding Amount                              -0.033493
# ...                                                    ...
# Decade Experience Ratio                          -0.317491
# Mid Career Experience Ratio                       1.000000
# Avg Gaps in Experience                            0.025730
# Avg Longest Position Duration                     0.035850
# Success                                          -0.007497
#
#                                Avg Gaps in Experience  \
# ID                                          -0.048625
# Number of Founders                           0.068494
# Number of Employees                         -0.003104
# Number of Funding Rounds                     0.062280
# Last Funding Amount                          0.044697
# ...                                               ...
# Decade Experience Ratio                      0.333269
# Mid Career Experience Ratio                  0.025730
# Avg Gaps in Experience                       1.000000
# Avg Longest Position Duration                0.272073
# Success                                      0.060534
#
#                                Avg Longest Position Duration   Success
# ID                                                 -0.062238 -0.082291
# Number of Founders                                  0.130321  0.155821
# Number of Employees                                -0.006128  0.158586
# Number of Funding Rounds                            0.210512  0.256907
# Last Funding Amount                                 0.042071  0.214912
# ...                                                      ...       ...
# Decade Experience Ratio                             0.801888  0.104709
# Mid Career Experience Ratio                         0.035850 -0.007497
# Avg Gaps in Experience                              0.272073  0.060534
# Avg Longest Position Duration                       1.000000  0.074709
# Success                                             0.074709  1.000000
#
# [117 rows x 117 columns]

# %%
feature_correlation_matrix = data.drop(columns=['Success']).corr()
upper_triangle = feature_correlation_matrix.where(np.triu(np.ones(feature_correlation_matrix.shape), k=1).astype(bool))
highly_correlated_features = [
    (feature_correlation_matrix.columns[col], feature_correlation_matrix.index[row], upper_triangle.iloc[row, col])
    for row in range(upper_triangle.shape[0])
    for col in range(row + 1, upper_triangle.shape[1])
    if abs(upper_triangle.iloc[row, col]) > 0.8
]

# Print highly correlated features
if highly_correlated_features:
    print("Strongly correlated feature pairs:")
    for feature1, feature2, correlation in highly_correlated_features:
        print(f"{feature1} and {feature2} with a correlation of {correlation:.2f}")
else:
    print("No strongly correlated features found.")

columns_to_drop = ['Was Acquired', 'IPO', 'High Funding']
data = data.drop(columns=columns_to_drop)
# Out:
# Strongly correlated feature pairs:
# Average Funding Size and Last Funding Amount with a correlation of 0.91
# X: Followers Max Growth and X: Followers with a correlation of 0.91
# X: Tweet Activity and X: Number of Tweets with a correlation of 0.93
# Average Time To Next Round and Months until First Round with a correlation of 0.87
# Average Number of Portfolio Organizations by Investors and Average Number of Investments by Investors with a correlation of 0.93
# Industry_data and analytics and Industry_artificial intelligence (ai) with a correlation of 0.84
# LinkedIn: Min Followers Founders and LinkedIn: Average Followers Founders with a correlation of 1.00
# LinkedIn: Max Followers Founders and LinkedIn: Average Followers Founders with a correlation of 1.00
# LinkedIn: Min Connections Founders and LinkedIn: Average Connections Founders with a correlation of 0.91
# LinkedIn: Max Connections Founders and LinkedIn: Average Connections Founders with a correlation of 0.93
# LinkedIn: Max Followers Founders and LinkedIn: Min Followers Founders with a correlation of 1.00
# All Firsttime Founders and Firsttime Founder Ratio with a correlation of 0.90
# Any Firsttime Founder and Firsttime Founder Ratio with a correlation of 0.92
# All Researchers and Researcher Ratio with a correlation of 0.84
# Any Researcher and Researcher Ratio with a correlation of 0.90
# All Executives and Executive Ratio with a correlation of 0.89
# Any Executive and Executive Ratio with a correlation of 0.92
# Avg Longest Position Duration and Decade Experience Ratio with a correlation of 0.80

# %%
data.to_csv("data.csv", index=False)
