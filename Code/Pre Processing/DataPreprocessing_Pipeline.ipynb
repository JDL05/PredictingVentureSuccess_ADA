# %% [markdown]
# # Data Preprocessing - Pipeline
# Explanation:

# %% [markdown]
# ## Import Packages
# pandas: A library for analyzing, cleaning, and manipulating structured data using DataFrames and Series. \
# os: A module for file system operations like creating, deleting, or navigating files and directories. \
# glob: A module to find file paths matching patterns (e.g., *.csv) for handling multiple files easily.

# %%
import pandas as pd
import os
from glob import glob

# %% [markdown]
# ## Companies Preprocessing
# Explanation:

# %%
def preprocess_companies(companies_files):
    all_companies = []

    for file in companies_files:
        companies_df = pd.read_csv(file)
        drop_columns = [
            'Total Funding Amount', 'Organization Name URL', 'Operating Status', 'Stage', 'Headquarters Regions', 'Closed Date',
            'Closed Date Precision', 'Company Type', 'Announced Date Precision', 'Price', 'Price Currency',
            'Price (in USD)', 'Acquisition Terms', 'Money Raised at IPO', 'Money Raised at IPO Currency',
            'Money Raised at IPO (in USD)', 'Valuation at IPO', 'Valuation at IPO Currency',
            'Valuation at IPO (in USD)', 'Stock Symbol', 'Stock Symbol URL', 'Stock Exchange',
            'Founded Date Precision', 'Exit Date Precision', 'Number of Events', 'IPO Date',
            'Transaction Name', 'Postal Code', 'Transaction Name URL', 'Estimated Revenue Range',
            'Headquarters Location', 'Last Funding Amount Currency', 'Last Equity Funding Amount Currency',
            'Total Equity Funding Amount Currency', 'Total Funding Amount Currency', 'Last Funding Amount (in USD)', 'Last Equity Funding Amount', 'Last Equity Funding Amount (in USD)', 'Last Equity Funding Type', 'Total Equity Funding Amount', 'Total Equity Funding Amount (in USD)', 'Funding Status', 'Acquired by URL', 'Acquisition Type',
        ]
        companies_df.drop(columns=drop_columns, inplace=True)

        mean_founders = companies_df['Number of Founders'].mean()
        companies_df['Number of Founders'] = companies_df['Number of Founders'].fillna(mean_founders)
        companies_df = companies_df.dropna(subset=['Number of Employees'])

        for col in ['Industries', 'Industry Groups']:
            companies_df[col] = companies_df[col].fillna('').apply(lambda x: [item.strip() for item in x.split(',')])

        def range_to_mean(value):
            low, high = map(int, value.split('-'))
            return (low + high) / 2

        companies_df['Number of Employees'] = companies_df['Number of Employees'].apply(range_to_mean)

        if 'Announced Date' in companies_df.columns:
            companies_df.rename(columns={'Announced Date': 'Announced Date Acquisition'}, inplace=True)

        for date_col in ['Founded Date', 'Exit Date', 'Last Funding Date', 'Announced Date Acquisition']:
            companies_df[date_col] = pd.to_datetime(companies_df[date_col])

        companies_df['IPO'] = companies_df['IPO Status'].map({'Public': 1, 'Private': 0})
        companies_df.drop(columns=['IPO Status'], inplace=True)

        for column in ['Number of Lead Investors', 'Number of Investors', 'Number of Acquisitions']:
            if column in companies_df.columns:
                companies_df[column] = companies_df[column].fillna(0)

        all_companies.append(companies_df)

    merged_companies = pd.concat(all_companies, ignore_index=True)

    merged_companies['ID'] = (merged_companies.index + 1).astype(str).str.zfill(6)

    merged_companies = merged_companies[['ID'] + [col for col in merged_companies.columns if col != 'ID']]

    return merged_companies

# %% [markdown]
# ## Funding Preprocessing
# Explanation:

# %%
def preprocess_funding(funding_files, companies_df):

    all_funding = pd.concat([pd.read_csv(file) for file in funding_files], ignore_index=True)

    drop_columns = [
        'Transaction Name', 'Transaction Name URL', 'Organization Name URL', 'Money Raised Currency',
        'Pre-Money Valuation Currency', 'Diversity Spotlight', 'Organization Location', 'Money Raised (in USD)',
        'Pre-Money Valuation (in USD)', 'Organization Description', 'Organization Industries',
        'Organization Website', 'Organization Revenue Range', 'Number of Partner Investors',
        'CB Rank (Funding Round)', 'Total Funding Amount Currency', 'Total Funding Amount (in USD)',
        'Funding Status', 'Equity Only Funding', 'Pre-Money Valuation', 'Total Funding Amount',
        'Number of Funding Rounds', 'Funding Stage'
    ]
    all_funding.drop(columns=drop_columns, inplace=True)

    all_funding = all_funding.merge(
        companies_df[['Organization Name', 'ID']],
        on='Organization Name', how='left'
    )
    all_funding.rename(columns={'ID': 'Company ID'}, inplace=True)
    all_funding['Company ID'] = all_funding['Company ID'].fillna('000000').astype(str).str.zfill(6)

    all_funding['Investor Names'] = all_funding['Investor Names'].fillna('').apply(
        lambda x: [item.strip() for item in x.split(',')]
    )
    all_funding['Announced Date'] = pd.to_datetime(all_funding['Announced Date'])

    all_funding = all_funding.reset_index(drop=True)
    all_funding['Funding ID'] = (all_funding.index + 1).astype(str).str.zfill(6)

    all_funding = all_funding[['Funding ID'] + [col for col in all_funding.columns if col != 'Funding ID']]

    return all_funding

# %% [markdown]
# ## Investors Preprocessing
# Explanation:

# %%
def preprocess_investors(investor_files):
    investor_dfs = []
    for file in investor_files:
        df = pd.read_csv(file)
        country = os.path.basename(file).split('-')[1].split('.')[0].upper()
        df['Country'] = country
        investor_dfs.append(df)
    investors = pd.concat(investor_dfs, ignore_index=True)
    investors.drop(columns=['Organization/Person Name URL', 'Investment Stage', 'Regions', 'Founded Date Precision'], inplace=True)

    investors['Investor ID'] = range(1, len(investors) + 1)
    investors['Investor ID'] = investors['Investor ID'].apply(lambda x: str(x).zfill(6))

    cols = ['Investor ID'] + [col for col in investors.columns if col != 'Investor ID']
    investors = investors[cols]

    return investors

# %% [markdown]
# ## Founders Preprocessing

# %%
def process_founders(companies, people):
    required_columns = ['first_name', 'last_name', 'linkedin_url', 'logo_url', 'facebook_url',
                        'twitter_url', 'city', 'region', 'country_code', 'featured_job_title',
                        'featured_job_organization_name']
    missing_columns = [col for col in required_columns if col not in people.columns]
    if missing_columns:
        raise ValueError(f"Missing columns in 'people': {missing_columns}")

    temp_companies = companies.copy()

    temp_companies['Founders'] = temp_companies['Founders'].fillna('').astype(str)
    temp_companies['Founders'] = temp_companies['Founders'].apply(lambda x: [item.strip() for item in x.split(',') if item.strip()])

    founders_table = temp_companies.explode('Founders', ignore_index=True)

    founders = founders_table[['ID', 'Founders', 'Organization Name']].rename(
        columns={'ID': 'Company ID', 'Founders': 'Founder Name'}
    )

    founders['Founder ID'] = founders.index + 1
    founders['Founder ID'] = founders['Founder ID'].astype(str).str.zfill(6)

    founders = founders[['Founder ID', 'Company ID', 'Founder Name', 'Organization Name']]
    founders = founders.dropna(subset=['Founder Name'])
    founders[['first_name', 'last_name']] = founders['Founder Name'].str.split(' ', n=1, expand=True)

    founders['linkedin_url'] = None

    string_columns = ['logo_url', 'facebook_url', 'twitter_url', 'city', 'region',
                      'country_code', 'featured_job_title', 'featured_job_organization_name']
    for col in string_columns:
        if col not in founders.columns:
            founders[col] = None
        founders[col] = founders[col].astype('str')

    duplicates = []

    for idx, row in founders.iterrows():
        matches = people[
            (people['first_name'] == row['first_name']) &
            (people['last_name'] == row['last_name'])
            ]
        if len(matches) == 0:
            continue
        elif len(matches) == 1:
            match = matches.iloc[0]
            founders.at[idx, 'linkedin_url'] = match['linkedin_url']
            for col in string_columns:
                founders.at[idx, col] = match[col]
        else:
            duplicates.append({
                'founder_id': row['Founder ID'],
                'first_name': row['first_name'],
                'last_name': row['last_name'],
                'matches': matches.to_dict('records')
            })

    print("\nResults with possible duplicates:")
    print(founders)

    print("\nList of Duplicates:")
    for duplicate in duplicates:
        print(f"Founder ID: {duplicate['founder_id']}, Name: {duplicate['first_name']} {duplicate['last_name']}")
        print("Matches:")
        for match in duplicate['matches']:
            print(f"  - LinkedIn: {match['linkedin_url']}")

    founders.to_csv("founders_with_links.csv", index=False)
    print("\nFile saved successfully: founders_with_links.csv")

    return founders

# %% [markdown]
# ## Pipeline Execution
# Explanation:

# %%
companies_files = glob('/Users/janlinzner/Library/Mobile Documents/com~apple~CloudDocs/Documents/McGill/1_Lectures/Decision Analytics (MGSC 662)/2_Coding/Exercises/ADA_Coding/Datasets/Companies/*.csv')
funding_files = glob('/Users/janlinzner/Library/Mobile Documents/com~apple~CloudDocs/Documents/McGill/1_Lectures/Decision Analytics (MGSC 662)/2_Coding/Exercises/ADA_Coding/Datasets/Funding/*.csv')
investor_files = glob('/Users/janlinzner/Library/Mobile Documents/com~apple~CloudDocs/Documents/McGill/1_Lectures/Decision Analytics (MGSC 662)/2_Coding/Exercises/ADA_Coding/Datasets/Investors/*.csv')

companies = preprocess_companies(companies_files)
funding = preprocess_funding(funding_files, companies)
investors = preprocess_investors(investor_files)

people = pd.read_csv("/Users/janlinzner/Library/Mobile Documents/com~apple~CloudDocs/Documents/McGill/1_Lectures/Decision Analytics (MGSC 662)/2_Coding/Exercises/ADA_Coding/Datasets/People/people_CB.csv")

founders = process_founders(companies, people)
# Out:
# Results with possible duplicates:
#      Founder ID Company ID             Founder Name Organization Name  \
# 0        000001     000001         Johannes Stoffel             2trde
# 1        000002     000002          Florian Ziesche     36ZERO Vision
# 2        000003     000002          Zeeshan Karamat     36ZERO Vision
# 3        000004     000003     Caroline Steingruber      3Bears Foods
# 4        000005     000003              Tim Nichols      3Bears Foods
# ...         ...        ...                      ...               ...
# 3136     003137     001508               Sven Peper           Taxy.io
# 3137     003138     001508               Sven Weber           Taxy.io
# 3138     003139     001509  Dr. Gennadi Schechtmann    TRINKKOST GmbH
# 3139     003140     001509            Timon Ortloff    TRINKKOST GmbH
# 3140     003141     001510           Tobias Kollewe   worqs Coworking
#
#      first_name            last_name  \
# 0      Johannes              Stoffel
# 1       Florian              Ziesche
# 2       Zeeshan              Karamat
# 3      Caroline          Steingruber
# 4           Tim              Nichols
# ...         ...                  ...
# 3136       Sven                Peper
# 3137       Sven                Weber
# 3138        Dr.  Gennadi Schechtmann
# 3139      Timon              Ortloff
# 3140     Tobias              Kollewe
#
#                                            linkedin_url  \
# 0     https://www.linkedin.com/in/johannes-stoffel-2...
# 1                                                  None
# 2                 https://www.linkedin.com/in/zkaramat/
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3136             https://www.linkedin.com/in/sven-peper
# 3137               http://www.linkedin.com/in/svenweber
# 3138                                               None
# 3139                                               None
# 3140          https://www.linkedin.com/in/tobiaskollewe
#
#                                                logo_url  \
# 0     https://images.crunchbase.com/image/upload/t_c...
# 1                                                  None
# 2     https://images.crunchbase.com/image/upload/t_c...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3136                                                NaN
# 3137  https://images.crunchbase.com/image/upload/t_c...
# 3138                                               None
# 3139                                               None
# 3140  https://images.crunchbase.com/image/upload/t_c...
#
#                                 facebook_url                  twitter_url  \
# 0                                        NaN                          NaN
# 1                                       None                         None
# 2                                        NaN                          NaN
# 3                                       None                         None
# 4                                       None                         None
# ...                                      ...                          ...
# 3136                                     NaN                          NaN
# 3137                                     NaN                          NaN
# 3138                                    None                         None
# 3139                                    None                         None
# 3140  https://www.facebook.com/tobiaskollewe  https://x.com/TobiasKollewe
#
#           city         region country_code  \
# 0       Munich         Bayern          DEU
# 1         None           None         None
# 2          NaN            NaN          NaN
# 3         None           None         None
# 4         None           None         None
# ...        ...            ...          ...
# 3136       NaN            NaN          NaN
# 3137   Concord  Massachusetts          USA
# 3138      None           None         None
# 3139      None           None         None
# 3140  Augsburg         Bayern          DEU
#
#                          featured_job_title featured_job_organization_name
# 0                          Co-Founder & CEO                        Karosso
# 1                                      None                           None
# 2     Chief Technology Officer & Co-Founder                  36ZERO Vision
# 3                                      None                           None
# 4                                      None                           None
# ...                                     ...                            ...
# 3136                       CEO & Co-Founder                        Taxy.io
# 3137                     Managing Principal     Knightsbridge Advisers LLC
# 3138                                   None                           None
# 3139                                   None                           None
# 3140                          CEO & Founder                         cowork
#
# [2918 rows x 15 columns]
#
# List of Duplicates:
# Founder ID: 000005, Name: Tim Nichols
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/tim-nichols-9a291921/
#   - LinkedIn: https://www.linkedin.com/in/tim-nichols-7a354a4
# Founder ID: 000013, Name: Maximilian Fischer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/maximilianpfischer
#   - LinkedIn: https://www.linkedin.com/in/maximilian-fischer-1ab7a214
# Founder ID: 000054, Name: Srinivas Rao
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/raosrinivas
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/srinivas-rao-77466226
#   - LinkedIn: https://www.linkedin.com/in/srinivas-rao-90155227
#   - LinkedIn: https://www.linkedin.com/in/ksrinivas-rao
# Founder ID: 000091, Name: Pedro Hernandez
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/pedrohsing
#   - LinkedIn: https://www.linkedin.com/in/pedrohernandezhernandez
# Founder ID: 000108, Name: Tobias Wagner
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/tobias-wagner-69bbb0a9/
#   - LinkedIn: https://www.linkedin.com/in/tobias-wagner-756b697a
#   - LinkedIn: https://www.linkedin.com/in/tobiaswagnerau
# Founder ID: 000116, Name: Guilherme Coelho
# Matches:
#   - LinkedIn: https://br.linkedin.com/in/guicoelho01
#   - LinkedIn: https://pt.linkedin.com/in/guipcoelho
# Founder ID: 000164, Name: Christian Becker
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christian-becker-394aba5/
#   - LinkedIn: https://www.linkedin.com/in/christian-becker-86a863174
#   - LinkedIn: https://www.linkedin.com/in/christian-becker-73a2196/?originalSubdomain=de
# Founder ID: 000200, Name: Nathan Evans
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/nwevans
#   - LinkedIn: https://www.linkedin.com/in/nathanpaulevans
#   - LinkedIn: https://www.linkedin.com/pub/nathan-evans/63/61a/300
#   - LinkedIn: https://www.linkedin.com/in/nathan-j-evans/
#   - LinkedIn: https://www.linkedin.com/in/nbevans/
# Founder ID: 000211, Name: Michael Ziegler
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michaelziegler2012
#   - LinkedIn: https://www.linkedin.com/in/michael-ziegler-b8ab9a89/
# Founder ID: 000217, Name: Matthew Fullerton
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/matthew-fullerton-60840931/
#   - LinkedIn: https://www.linkedin.com/in/matthew-fullerton-25826287
# Founder ID: 000262, Name: Florian Bauer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/florian-bauer-a230b333/
#   - LinkedIn: https://www.linkedin.com/in/florian-bauer-04b49197
#   - LinkedIn: https://www.linkedin.com/in/bauerflorian
# Founder ID: 000272, Name: Konstantin Korotkov
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/kkorotkov/
#   - LinkedIn: nan
# Founder ID: 000295, Name: Andrey Andreev
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/andrey-andreev-983a6521
#   - LinkedIn: https://www.linkedin.com/in/andreyvandreev
#   - LinkedIn: http://www.linkedin.com/andro
# Founder ID: 000359, Name: Andreas Eberhardt
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/eberhardtandreas
#   - LinkedIn: nan
# Founder ID: 000368, Name: Alexander Schneider
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/alexanderkschneider/
#   - LinkedIn: https://www.linkedin.com/in/alexander-schneider-939950192
# Founder ID: 000369, Name: Sebastian Müller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-ab07558
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-b1439754/
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-4752181/
#   - LinkedIn: https://www.linkedin.com/in/sebamuller/
# Founder ID: 000370, Name: Alexander Koenig
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/alexander-koenig-9731032b/
#   - LinkedIn: https://www.linkedin.com/in/koenigalexander/?locale=en_US
# Founder ID: 000371, Name: Philipp Kraft
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: http://www.linkedin.com/pub/philipp-kraft/1/917/9a3
#   - LinkedIn: https://www.linkedin.com/in/philippkraftvietswiss
# Founder ID: 000384, Name: David Hahn
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/davidwhahn
#   - LinkedIn: https://www.linkedin.com/in/hahnd
#   - LinkedIn: https://www.linkedin.com/in/david-hahn-136603a/
#   - LinkedIn: https://www.linkedin.com/in/davidhahnmunich/
#   - LinkedIn: https://www.linkedin.com/in/davidhahn1/
#   - LinkedIn: https://www.linkedin.com/in/whamo6955
#   - LinkedIn: https://www.linkedin.com/in/davidhahn
# Founder ID: 000394, Name: Christoph Niemann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/cniemann/
#   - LinkedIn: https://www.linkedin.com/in/christoph-niemann-b0bb40b7/
# Founder ID: 000416, Name: Adrian Lewis
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/adrian-lewis-17994014
#   - LinkedIn: https://www.linkedin.com/in/adriancodel/
#   - LinkedIn: https://www.linkedin.com/in/adrian-lewis-a7a71096
#   - LinkedIn: https://www.linkedin.com/in/adrian-lewis-he-him-his-90767a11
# Founder ID: 000450, Name: Michael Baumann
# Matches:
#   - LinkedIn: http://www.linkedin.com/pub/michael-baumann/5/bb0/256
#   - LinkedIn: http://www.linkedin.com/in/michaelbaumannphd
#   - LinkedIn: https://ch.linkedin.com/in/mibabaumann
#   - LinkedIn: https://www.linkedin.com/in/dr-michael-baumann-31868b113/
#   - LinkedIn: https://www.linkedin.com/in/michael-baumann-9a3955ab/
# Founder ID: 000474, Name: Marco Maier
# Matches:
#   - LinkedIn: https://de.linkedin.com/in/marco-maier-25442a99
#   - LinkedIn: https://www.linkedin.com/in/marcotm
# Founder ID: 000497, Name: Norman Hartmann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/normanhartmann
#   - LinkedIn: https://www.linkedin.com/in/norman-hartmann-baabb24/
# Founder ID: 000508, Name: Markus Schneider
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-9ba0859
#   - LinkedIn: https://www.linkedin.com/in/schneidermarkus
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-5b9a3296/
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-78b44619/
#   - LinkedIn: https://www.linkedin.com/in/dr-markus-schneider-27b47710/
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-b418a2130
#   - LinkedIn: nan
# Founder ID: 000515, Name: Simon Vogt
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/simon-vogt-a9a07931/
#   - LinkedIn: nan
# Founder ID: 000520, Name: Rahul Sharma
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-87644598
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-71a30b62?
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/rahulsharmanyc
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-3353b74
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-82b79b30
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/rahulsharma2008
#   - LinkedIn: https://www.linkedin.com/in/rahulsharma1981
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-955b9434/
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-2017b9a
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-493a7420
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-54a92a2a
#   - LinkedIn: https://www.linkedin.com/in/rahul-overseasdtp
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-99004648
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-711b42151/
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-0543292/
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-5050911bb/
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-087b285
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-9b038bb
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-4b345a6b
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-a46434bb
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-8b0b47a9
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-41a451b
#   - LinkedIn: https://www.linkedin.com/in/rahul-sharma-7078a01a
#   - LinkedIn: https://www.linkedin.com/in/rahulramansharma
# Founder ID: 000545, Name: Lars Olsson
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/lars-olsson-991a7921
#   - LinkedIn: https://www.linkedin.com/in/moinlars
#   - LinkedIn: https://www.linkedin.com/in/lars-olsson-12153460
#   - LinkedIn: nan
# Founder ID: 000549, Name: William Harris
# Matches:
#   - LinkedIn: https://www.linkedin.com/pub/william-harris/46/7a3/6a8
#   - LinkedIn: https://www.linkedin.com/in/wmharris
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/williamharrissfaz
#   - LinkedIn: https://www.linkedin.com/in/william-harris-818691/
#   - LinkedIn: https://www.linkedin.com/in/william-harris-5832b281/
#   - LinkedIn: https://www.linkedin.com/in/william-harris-384b27a5/
#   - LinkedIn: https://www.linkedin.com/in/harriswilliam1/
#   - LinkedIn: https://www.linkedin.com/in/william-harris2019/
#   - LinkedIn: https://www.linkedin.com/in/williammrharris
#   - LinkedIn: https://www.linkedin.com/in/will-harris-8675669
#   - LinkedIn: https://www.linkedin.com/in/william-harris-901b1b139
#   - LinkedIn: nan
# Founder ID: 000562, Name: Christopher Helm
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christopher-helm-063a8239
#   - LinkedIn: https://www.linkedin.com/in/c-helm/
# Founder ID: 000576, Name: Benjamin Michel
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/benjamin-michel-77483a2
#   - LinkedIn: https://www.linkedin.com/in/benjamin-michel-32687699
# Founder ID: 000593, Name: Sven Bauer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sven-bauer-82b654142/
#   - LinkedIn: https://www.linkedin.com/in/sven-bauer-0883a793/
#   - LinkedIn: https://www.linkedin.com/in/sven-bauer-a7599123
# Founder ID: 000597, Name: Joao Ferreira
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/jo%C3%A3o-filipe-tavares-ferreira-b01240a4
#   - LinkedIn: https://www.linkedin.com/in/jmnsf
# Founder ID: 000642, Name: George Michael
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/george-michael-828ab7106/
# Founder ID: 000706, Name: Marcel Kessler
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/marcel-kessler-841ab0169/
#   - LinkedIn: https://www.linkedin.com/in/marcelkessler
# Founder ID: 000712, Name: Jorge Díaz
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/xurde
#   - LinkedIn: nan
# Founder ID: 000723, Name: Robert Meyer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-4643295
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-56894b2/
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-alcemy
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-12231911
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-58a6aaa4
#   - LinkedIn: https://www.linkedin.com/in/robert-meyer-10190a41
# Founder ID: 000727, Name: Florian Frey
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/florian-frey-7ba76733
#   - LinkedIn: https://www.linkedin.com/in/flfrey
# Founder ID: 000741, Name: Matthew Dion
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/matthew-dion-90528155
#   - LinkedIn: https://www.linkedin.com/in/matthew-k-dion-phd-998b2236
# Founder ID: 000793, Name: Franz Hoerhager
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/franz-hoerhager
#   - LinkedIn: https://www.linkedin.com/in/franz-hoerhager-5293bb8a/
# Founder ID: 000813, Name: David Montiel
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/davidmontiel
# Founder ID: 000821, Name: Andreas Riedel
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/andreas-riedel-a328a461
#   - LinkedIn: https://www.linkedin.com/in/andreas-riedel-b3908034
#   - LinkedIn: https://www.linkedin.com/in/andreas-riedel-a76374118
# Founder ID: 000846, Name: Mohamed Abdulaziz
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/moabdulaziz/
#   - LinkedIn: https://www.linkedin.com/in/mohabdulaziz
# Founder ID: 000849, Name: Alessandro Rossi
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/alessandro-rossi-0193a56b
#   - LinkedIn: https://www.linkedin.com/in/alessandrorossi85
#   - LinkedIn: https://www.linkedin.com/in/alessandro-rossi-1792a5132
# Founder ID: 000887, Name: Christopher Becker
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/cfbecker
#   - LinkedIn: https://www.linkedin.com/in/christopherbecker
#   - LinkedIn: https://www.linkedin.com/in/christopher-becker-602357a
# Founder ID: 000897, Name: Oliver Neumann
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/oneumann/
# Founder ID: 000939, Name: Michael Vogel
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michaelvogel1
#   - LinkedIn: https://www.linkedin.com/in/michael-vogel-16095b103
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/michael-vogel-647b1136/
#   - LinkedIn: https://www.linkedin.com/in/michaelwvogel/
#   - LinkedIn: https://www.linkedin.com/in/mike-v-evolvematerials
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/michael-vogel-5062a77
# Founder ID: 000963, Name: Daniel Berndt
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/danielberndt/
#   - LinkedIn: https://www.linkedin.com/in/dr-daniel-berndt-5aa7a810/
# Founder ID: 000974, Name: Calvin Ng
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/ngcalvin
#   - LinkedIn: https://www.linkedin.com/in/calvinkn
# Founder ID: 000989, Name: Christoph Berner
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christophberner
#   - LinkedIn: https://www.linkedin.com/in/christoph-berner-129475109
# Founder ID: 000998, Name: Andrew Shaw
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/andrewshaw4/
#   - LinkedIn: https://www.linkedin.com/in/andrewshaw04
#   - LinkedIn: https://www.linkedin.com/in/andrew-shaw-phd
#   - LinkedIn: https://www.linkedin.com/in/andrew-shaw-38a8032
#   - LinkedIn: https://www.linkedin.com/in/andrew-shaw-6a95409a
#   - LinkedIn: https://www.linkedin.com/in/andrew-shaw-187b9036
# Founder ID: 001012, Name: Richard Hoffmann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/richardhoffmannvr/
#   - LinkedIn: https://www.linkedin.com/in/richard-hoffmann-6539054/
# Founder ID: 001015, Name: Daniel Fodor
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/danielfodor/
#   - LinkedIn: https://www.linkedin.com/in/fodordaniel
# Founder ID: 001034, Name: Zoltan Kovacs
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/zol-kovacs/
#   - LinkedIn: https://www.linkedin.com/in/zoltan-kovacs-1b304935
#   - LinkedIn: https://www.linkedin.com/in/zoltan-kovacs-72364617
# Founder ID: 001040, Name: David Meyer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/davidpmeyer
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/davidmeyer2
#   - LinkedIn: https://www.linkedin.com/in/123davidmeyer
#   - LinkedIn: https://www.linkedin.com/in/dave-meyer-5660846/
#   - LinkedIn: https://www.linkedin.com/in/david-meyer-12554725/
#   - LinkedIn: https://www.linkedin.com/in/david-meyer-0b60772
#   - LinkedIn: https://www.linkedin.com/in/thedmeyer
#   - LinkedIn: https://www.linkedin.com/in/davidmeyer88/
#   - LinkedIn: https://www.linkedin.com/in/admeyer
#   - LinkedIn: https://www.linkedin.com/in/davidmeyer3/
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/david-meyer-a6a71a61
# Founder ID: 001106, Name: Filipe Garcia
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/filipekramergarcia
#   - LinkedIn: https://www.linkedin.com/in/filipecgarcia/
# Founder ID: 001145, Name: Tim Meyer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/timeyer/
#   - LinkedIn: https://www.linkedin.com/in/tpmeyer
#   - LinkedIn: https://www.linkedin.com/in/meyercapitalmanagement
# Founder ID: 001164, Name: Robert Schumacher
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/drrobertschumacher/
#   - LinkedIn: https://www.linkedin.com/in/schumacherrobert/
# Founder ID: 001184, Name: Naveen Prasad
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/naveenkp
#   - LinkedIn: https://www.linkedin.com/in/inaveenpd
# Founder ID: 001188, Name: Christopher May
# Matches:
#   - LinkedIn: http://www.linkedin.com/pub/christopher-may/7/32b/1ba
#   - LinkedIn: https://www.linkedin.com/in/christopher-may-ab651574
#   - LinkedIn: https://www.linkedin.com/in/christopher-may-6b30a552/
#   - LinkedIn: https://www.linkedin.com/in/christopher-may27
# Founder ID: 001193, Name: Jake Jones
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/jake-jones-b8769b75/
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/jake-jones-a8720611a
# Founder ID: 001196, Name: David Jacob
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/dr-david-jacob-0a362515
#   - LinkedIn: https://www.linkedin.com/in/davidnotjacob/
# Founder ID: 001200, Name: Jon Nordby
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/jonnordby
#   - LinkedIn: https://www.linkedin.com/in/jonordby/
# Founder ID: 001203, Name: Peter Mitchell
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/peter-mitchell-5413874
#   - LinkedIn: https://www.linkedin.com/in/petemitchell
#   - LinkedIn: https://www.linkedin.com/in/realpeter/
#   - LinkedIn: https://www.linkedin.com/in/peterkmitchell
#   - LinkedIn: https://www.linkedin.com/in/peter-mitchell-37917612a/?originalSubdomain=uk
# Founder ID: 001269, Name: Thor Sigurdsson
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/thorarinn-sigurdsson-a4352123
#   - LinkedIn: https://www.linkedin.com/in/thorsigurdsson/
# Founder ID: 001271, Name: Maximilian Fischer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/maximilianpfischer
#   - LinkedIn: https://www.linkedin.com/in/maximilian-fischer-1ab7a214
# Founder ID: 001273, Name: Holger Weiss
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/holgerweiss
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 001296, Name: Jesus Mejia
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/jes%C3%BAs-mej%C3%ADa-gonz%C3%A1lez-33a4a62a/
#   - LinkedIn: https://www.linkedin.com/in/jesus-mejia-284972165
# Founder ID: 001304, Name: Chris King
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/chris-king-58586979
#   - LinkedIn: https://www.linkedin.com/in/chriskingcloud/
#   - LinkedIn: https://www.linkedin.com/in/kingchris
#   - LinkedIn: https://www.linkedin.com/in/chris-king-42a45152
#   - LinkedIn: https://www.linkedin.com/in/chris-king-7151197
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/chris-king-620a28b0/
#   - LinkedIn: https://www.linkedin.com/in/chris-king-b33a76/
#   - LinkedIn: https://www.linkedin.com/in/originalcvk/
#   - LinkedIn: https://www.linkedin.com/in/chris-king-768a596/
#   - LinkedIn: https://www.linkedin.com/in/chriskingjd
#   - LinkedIn: https://www.linkedin.com/in/chris-king-5729a110/
#   - LinkedIn: https://www.linkedin.com/in/cbking/
#   - LinkedIn: https://www.linkedin.com/in/chris-king-3a78365
#   - LinkedIn: https://www.linkedin.com/in/chris-king-32561b13
# Founder ID: 001307, Name: Thomas Warburton
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/thomas-warburton-5b115454/
#   - LinkedIn: nan
# Founder ID: 001311, Name: Jose Torres
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://linkedin.com/in/joseangeltorres
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/jose-torres-b366a62/
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 001318, Name: Sebastian Müller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-ab07558
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-b1439754/
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/sebastian-m%C3%BCller-4752181/
#   - LinkedIn: https://www.linkedin.com/in/sebamuller/
# Founder ID: 001320, Name: Ankur Bansal
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/ankurbansal
#   - LinkedIn: https://www.linkedin.com/in/ankur-bansal-blacksoil/
#   - LinkedIn: https://www.linkedin.com/in/ankurhbansal/
#   - LinkedIn: https://www.linkedin.com/in/ankurnbansal
#   - LinkedIn: https://www.linkedin.com/in/ankur-bansal-6aba8b12
# Founder ID: 001328, Name: Amit Gupta
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/amitgupta007/
#   - LinkedIn: https://www.linkedin.com/in/ca-amit-gupta-12179982/
#   - LinkedIn: http://www.linkedin.com/pub/amit-gupta/0/20/521
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-1ba8533
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-b01a4
#   - LinkedIn: https://www.linkedin.com/in/akg339
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-63700548
#   - LinkedIn: http://www.linkedin.com/in/gupta2
#   - LinkedIn: https://www.linkedin.com/pub/amit-gupta/1/bb1/847
#   - LinkedIn: http://www.linkedin.com/in/amitngupta
#   - LinkedIn: http://www.linkedin.com/in/amitgupta
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-b64a8118
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/amitgpt
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-09a096a
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-6490b821
#   - LinkedIn: https://www.linkedin.com/in/amtg
#   - LinkedIn: https://www.linkedin.com/in/profileofamitgupta/
#   - LinkedIn: https://www.linkedin.com/in/amitguptaisb/
#   - LinkedIn: https://www.linkedin.com/in/caamit1981/
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-00386980/
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-b892706/
#   - LinkedIn: https://www.linkedin.com/in/amitgupta25
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-149a8155/?originalSubdomain=in
#   - LinkedIn: https://www.linkedin.com/in/aggupta/
#   - LinkedIn: https://www.linkedin.com/in/itauditor/
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-8442811b
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-5320171
#   - LinkedIn: https://www.linkedin.com/in/amitguptaast
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-7387365
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-661570192/
#   - LinkedIn: nan
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/amitguptamahikapackaging
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-92369136
#   - LinkedIn: https://www.linkedin.com/in/amit-gupta-082256
#   - LinkedIn: nan
# Founder ID: 001340, Name: Markus Schneider
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-9ba0859
#   - LinkedIn: https://www.linkedin.com/in/schneidermarkus
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-5b9a3296/
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-78b44619/
#   - LinkedIn: https://www.linkedin.com/in/dr-markus-schneider-27b47710/
#   - LinkedIn: https://www.linkedin.com/in/markus-schneider-b418a2130
#   - LinkedIn: nan
# Founder ID: 001350, Name: Daniel Deutsch
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/daniel-deutsch
#   - LinkedIn: https://www.linkedin.com/in/daniel-deutsch-405b0413/
#   - LinkedIn: https://www.linkedin.com/in/danieldeutschmetro/
# Founder ID: 001368, Name: Sebastian Klein
# Matches:
#   - LinkedIn: https://de.linkedin.com/pub/sebastian-klein/7a/25/4b2/en
#   - LinkedIn: https://www.linkedin.com/in/sebastianklein59
# Founder ID: 001385, Name: Sebastian Hahn
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sebastian-hahn-98b36080
#   - LinkedIn: https://www.linkedin.com/in/sebashahn/?originalSubdomain=ar
# Founder ID: 001390, Name: Daniel Winter
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/daniel-the-winter
#   - LinkedIn: https://www.linkedin.com/in/daniel-winter-403059118/
# Founder ID: 001398, Name: Christoph Lange
# Matches:
#   - LinkedIn: https://de.linkedin.com/in/christophlange
#   - LinkedIn: https://www.linkedin.com/in/christophdlange/
# Founder ID: 001401, Name: Michael Stephan
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michaeltobiasstephan/
#   - LinkedIn: https://www.linkedin.com/in/michaelstephan/
# Founder ID: 001430, Name: Florian Mann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/florianmann/
#   - LinkedIn: https://www.linkedin.com/in/dr-florian-mann-76965016a
# Founder ID: 001466, Name: Dimitrios Ploutarchos
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/dploutarchos
#   - LinkedIn: https://www.linkedin.com/in/dploutarchos/
# Founder ID: 001481, Name: David Padilla
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/davidpadilla
#   - LinkedIn: https://www.linkedin.com/in/davidpadillazh
# Founder ID: 001490, Name: Christian Schiller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/cnschiller
#   - LinkedIn: https://www.linkedin.com/in/chschiller/
# Founder ID: 001507, Name: Steve Miller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/stevemiller18
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-292aa
#   - LinkedIn: https://www.linkedin.com/in/stephen-miller-42725811
#   - LinkedIn: https://www.linkedin.com/in/consultingdirector
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-b611617
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/stevecmill/
#   - LinkedIn: https://www.linkedin.com/in/stephenpmiller/
#   - LinkedIn: https://www.linkedin.com/in/stevekmiller4/
#   - LinkedIn: https://www.linkedin.com/in/stephen-miller-2380534/
#   - LinkedIn: https://www.linkedin.com/in/stevemillerok/
#   - LinkedIn: https://www.linkedin.com/in/stevenumiller/
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-0387a510/
#   - LinkedIn: https://www.linkedin.com/in/steve27miller/
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-3558b0133
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-15799811
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-34191167
#   - LinkedIn: https://www.linkedin.com/in/stevemillertool
#   - LinkedIn: https://www.linkedin.com/in/stevenmillerwellandlaike
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-84413a18
#   - LinkedIn: https://www.linkedin.com/in/steve-miller-439bb79
# Founder ID: 001512, Name: Lukas Weiss
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/linkedlukasweiss/
#   - LinkedIn: https://www.linkedin.com/in/lukas-weiss
# Founder ID: 001532, Name: Christian Zimmermann
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/christianzimmermann1989
#   - LinkedIn: https://www.linkedin.com/in/christian-zimmermann-68a43b158/
# Founder ID: 001551, Name: Stavros Papadopoulos
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/stavrospap/
#   - LinkedIn: https://www.linkedin.com/in/s-papadopoulos
# Founder ID: 001565, Name: Paul Becker
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/paulbckr
#   - LinkedIn: https://www.linkedin.com/in/paul-becker-3823b512/
# Founder ID: 001585, Name: Tobias Teuber
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/tobiasteuber/?originalSubdomain=de
# Founder ID: 001613, Name: Felix Jahn
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/felixjahn/
#   - LinkedIn: https://www.linkedin.com/in/jahnfelix/
# Founder ID: 001616, Name: Kilian Thalhammer
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/kilianthalhammer
#   - LinkedIn: nan
# Founder ID: 001646, Name: Maximilian Fischer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/maximilianpfischer
#   - LinkedIn: https://www.linkedin.com/in/maximilian-fischer-1ab7a214
# Founder ID: 001664, Name: Nathan Williams
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/nathan-williams-53587135/
#   - LinkedIn: https://www.linkedin.com/in/nathanwilliamsmba/
#   - LinkedIn: http://ca.linkedin.com/pub/nathan-williams/36/90/50
#   - LinkedIn: https://www.linkedin.com/in/nwilliamsscu
#   - LinkedIn: https://www.linkedin.com/in/nathanaeljwilliams/
#   - LinkedIn: https://www.linkedin.com/in/nathan-williams-1796b552
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/nathan-williams-0b5a4090
#   - LinkedIn: https://www.linkedin.com/in/nathan-williams-8223b115
# Founder ID: 001669, Name: Mike Richardson
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/mike-richardson-a9632131
#   - LinkedIn: https://www.linkedin.com/in/mike-richardson-20a0841a
#   - LinkedIn: https://www.linkedin.com/in/mike-richardson-575059209
#   - LinkedIn: https://www.linkedin.com/in/ahmloans
#   - LinkedIn: nan
# Founder ID: 001712, Name: Mark Hartmann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/mark-hartmann-0387ba1
#   - LinkedIn: https://www.linkedin.com/in/mark-w-hartmann
# Founder ID: 001732, Name: Robert Langer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/robert-langer-67944026
#   - LinkedIn: https://www.linkedin.com/in/robert-langer-43782a110/
#   - LinkedIn: https://www.linkedin.com/in/langerrobert/
#   - LinkedIn: nan
# Founder ID: 001746, Name: Sunil Yadav
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/sunil-r-yadav-26b31018b
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/sunil-yadav-9804315a/
# Founder ID: 001760, Name: Manjunath Ramesh
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/manjunathramesh1
#   - LinkedIn: https://www.linkedin.com/in/manjunath-ramesh
# Founder ID: 001802, Name: Michael Walser
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michael-walser-3558a25a
#   - LinkedIn: https://www.linkedin.com/in/krisdarby
# Founder ID: 001805, Name: Christian Wolf
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christian-wolf-b992341
#   - LinkedIn: https://www.linkedin.com/in/chriwo
# Founder ID: 001813, Name: Daniel Harvey
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/danielsharvey
#   - LinkedIn: https://www.linkedin.com/in/daniel-harvey-369a47b4/
# Founder ID: 001818, Name: David Brandes
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/david-brandes
# Founder ID: 001861, Name: Karl Singer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/karl-singer-05611019
#   - LinkedIn: https://www.linkedin.com/in/karl-singer-6babb0182
# Founder ID: 001864, Name: Benedikt Franke
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/benedikt-franke
#   - LinkedIn: https://www.linkedin.com/in/benedikt-franke-7a970984
# Founder ID: 001878, Name: Max Mueller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/muellermaxmobil
#   - LinkedIn: https://www.linkedin.com/in/max-mueller-709b79144
# Founder ID: 001893, Name: Stefan Schmidt
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/stefan-schmidt-a3711b114
#   - LinkedIn: https://www.linkedin.com/in/stefanrschmidt
#   - LinkedIn: https://www.linkedin.com/in/stefan-schmidt-london/
#   - LinkedIn: https://www.linkedin.com/in/stefan-schmidt-585275b
# Founder ID: 001925, Name: James Gross
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/jamesgross
#   - LinkedIn: https://www.linkedin.com/in/james-gross-5690135
#   - LinkedIn: https://www.linkedin.com/in/james-gross-6b8912
# Founder ID: 001945, Name: Michael Schramm
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michaeltschramm
#   - LinkedIn: https://www.linkedin.com/in/ms07at
#   - LinkedIn: https://www.linkedin.com/in/schrammmichael
#   - LinkedIn: https://www.linkedin.com/in/michael-schramm-7974b22/
# Founder ID: 001953, Name: Christian Lang
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christian-lang-b672a4b8/
#   - LinkedIn: https://www.linkedin.com/in/christian-lang-614944b4
# Founder ID: 001977, Name: Florian Frey
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/florian-frey-7ba76733
#   - LinkedIn: https://www.linkedin.com/in/flfrey
# Founder ID: 001978, Name: Stefan Ritter
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/stefanrittergermany/
#   - LinkedIn: https://www.linkedin.com/in/stefanritter
# Founder ID: 001990, Name: Benedikt Franke
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/benedikt-franke
#   - LinkedIn: https://www.linkedin.com/in/benedikt-franke-7a970984
# Founder ID: 002025, Name: Felix Müller
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/muellerfe/
# Founder ID: 002026, Name: Luke Miller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/lukemiller1
#   - LinkedIn: https://www.linkedin.com/in/lukelucasmiller/
#   - LinkedIn: https://www.linkedin.com/in/luke-miller-573875b2
#   - LinkedIn: https://www.linkedin.com/in/lukermiller
#   - LinkedIn: https://www.linkedin.com/in/luke-miller-76a6461b0
#   - LinkedIn: https://www.linkedin.com/in/luke-miller-095093185
# Founder ID: 002027, Name: Philipp Müller
# Matches:
#   - LinkedIn: https://de.linkedin.com/in/philippmueller
#   - LinkedIn: https://www.linkedin.com/in/m%C3%BCller/
# Founder ID: 002029, Name: Moti Tal
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/motit
#   - LinkedIn: https://www.linkedin.com/in/moti-tal-126b566/
# Founder ID: 002042, Name: Felix Haas
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/felixhaas
#   - LinkedIn: https://www.linkedin.com/in/botho81/
#   - LinkedIn: https://www.linkedin.com/in/felix-haas-285110105/
# Founder ID: 002069, Name: Artur Mkrtchyan
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/arturmkrtchyan/
#   - LinkedIn: https://www.linkedin.com/in/artur-mkrtchyan-6ba3699
# Founder ID: 002079, Name: Christian Blomberg
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/christian-blomberg-8b260398
# Founder ID: 002087, Name: Ran Oren
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/ran-oren-3a31092
#   - LinkedIn: https://www.linkedin.com/in/ran-oren-530bb318
#   - LinkedIn: https://www.linkedin.com/in/ranoren1/?originalSubdomain=uk
# Founder ID: 002143, Name: Christian Lang
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christian-lang-b672a4b8/
#   - LinkedIn: https://www.linkedin.com/in/christian-lang-614944b4
# Founder ID: 002149, Name: Edward Taylor
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/edwardctaylor
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/edtau/
# Founder ID: 002160, Name: Jason Reich
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/jasonjreich
# Founder ID: 002166, Name: Sebastian Haas
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/haas-sebastian
#   - LinkedIn: https://www.linkedin.com/in/sebastianoskarhaas/
# Founder ID: 002228, Name: Christian Gonzalez
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christianggonzalez
#   - LinkedIn: https://www.linkedin.com/in/christian-daniel-venegas-gonz%C3%A1lez-34109a82/
#   - LinkedIn: https://www.linkedin.com/in/christian-gonzalez-ba31ab61/
# Founder ID: 002243, Name: Martin Polak
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/martinpolak
#   - LinkedIn: https://www.linkedin.com/in/martin-polak-8164b075/?originalSubdomain=sk
# Founder ID: 002261, Name: Alexander Franke
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/alexander-franke-4113b272
#   - LinkedIn: http://www.linkedin.com/in/alexanderfranke
# Founder ID: 002273, Name: Paul Dittrich
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/paul-dittrich-381738183/
#   - LinkedIn: nan
# Founder ID: 002288, Name: Stephan Müller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/stephanmueller1
#   - LinkedIn: https://www.linkedin.com/in/stephan-m%C3%BCller-219a9214b
# Founder ID: 002299, Name: Holger Friedrich
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 002310, Name: Katherine Liu
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/katherine-liu-2a0896126
#   - LinkedIn: https://www.linkedin.com/in/tokatherineliu
# Founder ID: 002369, Name: Alexander Müller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/graubner/en
#   - LinkedIn: nan
#   - LinkedIn: https://de.linkedin.com/in/dr-alexander-m%C3%BCller-1715a7132
#   - LinkedIn: https://www.linkedin.com/in/alexander-m%C3%BCller-88194711
#   - LinkedIn: https://www.linkedin.com/in/alexander-c-mueller
#   - LinkedIn: https://www.linkedin.com/in/alexander-m%C3%BCller-74486a99
# Founder ID: 002380, Name: Michael Huth
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michael-huth-b5109917/
#   - LinkedIn: https://www.linkedin.com/in/michaelhuth67
# Founder ID: 002401, Name: Sascha Guenther
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sascha-guenther-2314a5a2
#   - LinkedIn: https://www.linkedin.com/in/sascha-guenther-24ba5160
# Founder ID: 002415, Name: Daniel Werner
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/daniel-werner-216259a
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/wernerdaniel
#   - LinkedIn: https://www.linkedin.com/in/daniel-werner-40a005171/
# Founder ID: 002426, Name: Benjamin Projdakov
# Matches:
#   - LinkedIn: https://de.linkedin.com/in/benjaminprojdakov/en
#   - LinkedIn: https://www.linkedin.com/in/benjaminprojdakov
# Founder ID: 002458, Name: Johannes Keller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/johannes-keller-22a5b6162/
#   - LinkedIn: https://www.linkedin.com/in/johanneskeller/
# Founder ID: 002469, Name: Simon Müller
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/simon-m%C3%BCller
# Founder ID: 002494, Name: Neil Dsouza
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/neildsouz
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/neilsaviodsouza/?originalSubdomain=de
#   - LinkedIn: https://www.linkedin.com/in/neil-d-souza-b0b3331/
# Founder ID: 002514, Name: Martin Weber
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/martin-weber-24055b
#   - LinkedIn: https://www.linkedin.com/in/martin-weber-716abb10a
#   - LinkedIn: https://www.linkedin.com/in/martin-weber-696057a0
#   - LinkedIn: https://www.linkedin.com/in/martiniweber
#   - LinkedIn: https://www.linkedin.com/in/martin-weber-72890794
# Founder ID: 002532, Name: Boris Polenske
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: http://www.linkedin.com/in/borispolenske
# Founder ID: 002544, Name: Sven Müller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sven-m%C3%BCller-56255727/
#   - LinkedIn: https://www.linkedin.com/in/sven-m%C3%BCller-autlay
# Founder ID: 002551, Name: Frank Schaefer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/frank-schaefer-4079221
#   - LinkedIn: https://www.linkedin.com/in/frank-schaefer-6b034b36/
#   - LinkedIn: https://www.linkedin.com/in/frankjschaefer/
# Founder ID: 002572, Name: William Lyons
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/william-lyons-eekual/
#   - LinkedIn: https://www.linkedin.com/in/will-lyons-73b154195
# Founder ID: 002576, Name: Christoph Bauer
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christoph-bauer-2651513/
#   - LinkedIn: https://www.linkedin.com/in/christoph-bauer-98027b54
#   - LinkedIn: https://www.linkedin.com/in/christoph-bauer-22764a1b5/
# Founder ID: 002707, Name: Konrad Krawczyk
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/konradkrawc/
#   - LinkedIn: https://www.linkedin.com/in/konrad-krawczyk-3111a2211
# Founder ID: 002726, Name: Sascha Kuntze
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/skuntze/
#   - LinkedIn: https://www.linkedin.com/in/saschakuntze/
# Founder ID: 002741, Name: Christian Schiller
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/cnschiller
#   - LinkedIn: https://www.linkedin.com/in/chschiller/
# Founder ID: 002787, Name: Peter Mitchell
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/peter-mitchell-5413874
#   - LinkedIn: https://www.linkedin.com/in/petemitchell
#   - LinkedIn: https://www.linkedin.com/in/realpeter/
#   - LinkedIn: https://www.linkedin.com/in/peterkmitchell
#   - LinkedIn: https://www.linkedin.com/in/peter-mitchell-37917612a/?originalSubdomain=uk
# Founder ID: 002804, Name: Javier Sanchez
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/jsanchezsierra
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/jjsanchez1/
#   - LinkedIn: https://www.linkedin.com/in/javier-sanchez-68a91217
# Founder ID: 002825, Name: Sabrina Beck
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sabrina-beck-8233aa93/
#   - LinkedIn: https://www.linkedin.com/in/sabrinabeck1
# Founder ID: 002854, Name: X.Employee Name
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 002859, Name: Felix Kühl
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/felix-kuehl-7135757a
#   - LinkedIn: https://www.linkedin.com/in/felix-k%C3%BChl-b28036154/
# Founder ID: 002868, Name: Richard Ruben
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: http://www.linkedin.com/pub/richard-ruben/60/306/2aa
# Founder ID: 002873, Name: Robert Weber
# Matches:
#   - LinkedIn: http://www.linkedin.com/in/robertjweber
#   - LinkedIn: https://www.linkedin.com/in/robertweber-knowhere
#   - LinkedIn: https://www.linkedin.com/in/robert-weber-1a3780/
#   - LinkedIn: https://www.linkedin.com/in/bob-weber-6980a8b
#   - LinkedIn: https://www.linkedin.com/in/robert-weber-259077263
# Founder ID: 002874, Name: Sebastian Schmitt
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sebastian-schmitt-b9b9498
#   - LinkedIn: https://www.linkedin.com/in/sebastian-schmitt1
# Founder ID: 002876, Name: Sebastian Scheele
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/sebastian-scheele-a03ab2b3
#   - LinkedIn: https://www.linkedin.com/in/sebastian-scheele/
# Founder ID: 002892, Name: Michael Merz
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/dr-michael-merz-1a5433/
#   - LinkedIn: https://www.linkedin.com/in/mmerz/
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 002894, Name: Mark Witt
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 002910, Name: Tobias Lang
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: nan
#   - LinkedIn: nan
# Founder ID: 002917, Name: Michael Carlin
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/michael-carlin-09365922
#   - LinkedIn: https://www.linkedin.com/in/micc
#   - LinkedIn: https://www.linkedin.com/in/michael-carlin-84932413
# Founder ID: 002939, Name: Fahad Khan
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/fahad-khan-b2483b21
#   - LinkedIn: https://www.linkedin.com/in/fk123/
#   - LinkedIn: https://www.linkedin.com/in/fahad-khan-6bb1084
# Founder ID: 002957, Name: Peter König
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/peter-k%C3%B6nig-1741745
#   - LinkedIn: https://www.linkedin.com/in/peter-k%C3%B6nig-41578718a
# Founder ID: 002971, Name: Gary Lewis
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-977b161
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-b7ab3412
#   - LinkedIn: https://www.linkedin.com/in/garynz/
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-61b4564
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-92541118
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-9608bab
#   - LinkedIn: https://www.linkedin.com/in/gary-lewis-78b27064
#   - LinkedIn: https://www.linkedin.com/in/garylewisautocareeerpro/
# Founder ID: 003047, Name: Mike Lohmann
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/mike-lohmann-b764082/
#   - LinkedIn: https://www.linkedin.com/in/mike-h-lohmann
#   - LinkedIn: https://www.linkedin.com/in/mike-lohmann-3a213116/
# Founder ID: 003048, Name: Jan Rabe
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/jan-rabe-68a070108/
#   - LinkedIn: https://www.linkedin.com/in/janrabe/
# Founder ID: 003054, Name: Philipp Weber
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/philippcweber/
#   - LinkedIn: https://www.linkedin.com/in/phiweber/
# Founder ID: 003086, Name: Günther Schuh
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/g%C3%BCnther-schuh-a01b3191
#   - LinkedIn: nan
# Founder ID: 003099, Name: Andrea Benigni
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/andrea-benigni-66a1b911
# Founder ID: 003122, Name: David Link
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/dalink
#   - LinkedIn: https://www.linkedin.com/in/jdavidlink
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/davidclink/
# Founder ID: 003132, Name: Christian Bartsch
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/christian-bartsch-b643688
#   - LinkedIn: https://www.linkedin.com/in/christian-bartsch-328433110
# Founder ID: 003133, Name: Thomas Grimm
# Matches:
#   - LinkedIn: https://www.linkedin.com/in/thomas-grimm-6a9242227
#   - LinkedIn: https://www.linkedin.com/in/thomas-grimm-b54635b7
# Founder ID: 003135, Name: Daniel Kirch
# Matches:
#   - LinkedIn: nan
#   - LinkedIn: https://www.linkedin.com/in/danielkirch/
#
# File saved successfully: founders_with_links.csv

# %% [markdown]
# ## Validation

# %%
companies
companies.to_csv("companies.csv", index=False)

# %%
funding
funding.to_csv("funding.csv", index=False)

# %%
investors
investors.to_csv("investors.csv", index=False)

# %% [markdown]
# ## Next Steps
# Explanation:
